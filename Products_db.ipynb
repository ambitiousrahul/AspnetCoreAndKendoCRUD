-- %% [markdown]
-- # [dbo].[Product]

-- %%
/****** Object:  Table [dbo].[Product]    Script Date: 17-09-2022 08:44:55 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Product](
	[ProductCode] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](64) NOT NULL,
	[CategoryId] [int] NOT NULL,
	[UnitPrice] [int] NOT NULL,
	[ManufactureDate] [datetime2](7) NULL,
	[IsActive] [bit] NOT NULL,
	[AddedDate] [datetime2](7) NOT NULL,
	[LastEditedDate] [datetime2](7) NULL,
 CONSTRAINT [PK_Product] PRIMARY KEY CLUSTERED 
(
	[ProductCode] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProductCategory]

-- %%
/****** Object:  Table [dbo].[ProductCategory]    Script Date: 17-09-2022 08:44:55 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProductCategory](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](64) NOT NULL,
	[Description] [varchar](200) NULL,
	[AddedDate] [datetime2](7) NOT NULL,
	[LastEditedDate] [datetime2](7) NOT NULL,
 CONSTRAINT [PK_ProductCategory] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [UQ_ProductName]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ_ProductName]    Script Date: 17-09-2022 08:44:58 ******/
ALTER TABLE [dbo].[Product] ADD  CONSTRAINT [UQ_ProductName] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [UQ_ProductCategoryName]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ_ProductCategoryName]    Script Date: 17-09-2022 08:44:58 ******/
ALTER TABLE [dbo].[ProductCategory] ADD  CONSTRAINT [UQ_ProductCategoryName] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Product_ProductCategory]

-- %%
ALTER TABLE [dbo].[Product]  WITH CHECK ADD  CONSTRAINT [FK_Product_ProductCategory] FOREIGN KEY([CategoryId])
REFERENCES [dbo].[ProductCategory] ([Id])
GO
ALTER TABLE [dbo].[Product] CHECK CONSTRAINT [FK_Product_ProductCategory]
GO

-- %% [markdown]
-- # [dbo].[ProductCategory]

-- %%
SET IDENTITY_INSERT [dbo].[ProductCategory] ON 
INSERT [dbo].[ProductCategory] ([Id], [Name], [Description], [AddedDate], [LastEditedDate]) VALUES (1, N'Fashion', N'Fashion Category', CAST(N'2022-09-14T00:00:00.0000000' AS DateTime2), CAST(N'2022-09-15T00:00:00.0000000' AS DateTime2))
INSERT [dbo].[ProductCategory] ([Id], [Name], [Description], [AddedDate], [LastEditedDate]) VALUES (2, N'Electronics', N'Electronics Category', CAST(N'2022-09-14T00:00:00.0000000' AS DateTime2), CAST(N'2022-09-15T00:00:00.0000000' AS DateTime2))
INSERT [dbo].[ProductCategory] ([Id], [Name], [Description], [AddedDate], [LastEditedDate]) VALUES (3, N'Grocery', N'Groceries category', CAST(N'2022-09-15T00:00:00.0000000' AS DateTime2), CAST(N'2022-09-15T00:00:00.0000000' AS DateTime2))
SET IDENTITY_INSERT [dbo].[ProductCategory] OFF
GO

-- %% [markdown]
-- # [dbo].[Product]

-- %%
SET IDENTITY_INSERT [dbo].[Product] ON 
INSERT [dbo].[Product] ([ProductCode], [Name], [CategoryId], [UnitPrice], [ManufactureDate], [IsActive], [AddedDate], [LastEditedDate]) VALUES (1, N'Product2', 1, 2000, CAST(N'2021-12-31T23:36:32.0000000' AS DateTime2), 0, CAST(N'2021-12-31T23:36:32.0000000' AS DateTime2), CAST(N'2022-09-16T16:16:53.3825758' AS DateTime2))
SET IDENTITY_INSERT [dbo].[Product] OFF
GO
